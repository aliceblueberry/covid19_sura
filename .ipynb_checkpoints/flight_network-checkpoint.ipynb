# %%
from US_Flight_Data import df_normalized

# %%
data_t = df_normalized.itertuples()
for row in data_t:
    print(data_t)

# %%
print(df_normalized)
# Out:
#                                  PASSENGERS
# ORIGIN_STATE_ABR DEST_STATE_ABR
# AK               AK                0.867097
#                  AZ                0.553167
#                  CA                0.582268
#                  CO                0.585884
#                  HI                0.633841
#                  MN                0.596899
#                  OR                0.630873
#                  WA                0.808356
# AL               AL                0.118301
#                  AZ                0.425136
#                  CO                0.614209
#                  FL                0.666806
#                  GA                0.772554
#                  IL                0.658954
#                  KY                0.188535
#                  MD                0.526296
#                  MI                0.597161
#                  NC                0.702899
#                  NJ                0.143033
#                  NV                0.553207
# ...
